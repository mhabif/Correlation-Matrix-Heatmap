# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
# %matplotlib inline

# %%
#Import data-sets
data_002 = pd.read_csv('002_MyExpt_Trans_1MS.csv',delimiter=',')#, dtype = float)
data_005 = pd.read_csv('005_MyExpt_Trans_1MS.csv',delimiter=',')#, dtype = float)
data_006 = pd.read_csv('006_MyExpt_Trans_1MS.csv',delimiter=',')#, dtype = float)
data_007 = pd.read_csv('007_MyExpt_Trans_1MS.csv',delimiter=',')#, dtype = float)
data_009 = pd.read_csv('009_MyExpt_Trans_1MS.csv',delimiter=',')#, dtype = float)
data_010 = pd.read_csv('010_MyExpt_Trans_1MS.csv',delimiter=',')#, dtype = float)
data_012 = pd.read_csv('012_MyExpt_Trans_1MS.csv',delimiter=',')#, dtype = float)

# %%
#Create a Sorted DataFrame
datasorted_002 = data_002.sort_values(by=['ImageNumber'],ascending=[1])
datasorted_005 = data_005.sort_values(by=['ImageNumber'],ascending=[1])
datasorted_006 = data_006.sort_values(by=['ImageNumber'],ascending=[1])
datasorted_007 = data_007.sort_values(by=['ImageNumber'],ascending=[1])
datasorted_009 = data_009.sort_values(by=['TrackObjects_Label_1500','ImageNumber'],ascending=[1,1])
datasorted_010 = data_010.sort_values(by=['TrackObjects_Label_1500','ImageNumber'],ascending=[1,1])
datasorted_012 = data_012.sort_values(by=['ImageNumber'],ascending=[1])

# %%
#subset of rows
df_002 = datasorted_002.iloc[0:140]
df_005 = datasorted_005.iloc[0:140]
df_006 = datasorted_006.iloc[0:140]
df_007 = datasorted_007.iloc[0:140]
df_009 = datasorted_009.iloc[0:140]
df_010 = datasorted_010.iloc[0:140]
df_012 = datasorted_012.iloc[0:140]

# %%
#Column to values (array) + aspect ratio calculation
df_002_Area = df_002.AreaShape_Area.values[0:161] 
df_002_Perimeter = df_002.AreaShape_Perimeter.values[0:161] 
df_002_Solidity = df_002.AreaShape_Solidity.values[0:161] 
df_002_Extent = df_002.AreaShape_Extent.values[0:161] 
df_002_MajorAxisLength = df_002.AreaShape_MajorAxisLength.values[0:161] 
df_002_MinorAxisLength = df_002.AreaShape_MinorAxisLength.values[0:161] 
df_002_Compactness = df_002.AreaShape_Compactness.values[0:161] 
df_002_Eccentricity = df_002.AreaShape_Eccentricity.values[0:161]

#=======================================================================

df_005_Area = df_005.AreaShape_Area.values[0:161] 
df_005_Perimeter = df_005.AreaShape_Perimeter.values[0:161] 
df_005_Solidity = df_005.AreaShape_Solidity.values[0:161] 
df_005_Extent = df_005.AreaShape_Extent.values[0:161] 
df_005_MajorAxisLength = df_005.AreaShape_MajorAxisLength.values[0:161] 
df_005_MinorAxisLength = df_005.AreaShape_MinorAxisLength.values[0:161] 
df_005_Compactness = df_005.AreaShape_Compactness.values[0:161] 
df_005_Eccentricity = df_005.AreaShape_Eccentricity.values[0:161]

#=======================================================================

df_006_Area = df_006.AreaShape_Area.values[0:161] 
df_006_Perimeter = df_006.AreaShape_Perimeter.values[0:161] 
df_006_Solidity = df_006.AreaShape_Solidity.values[0:161] 
df_006_Extent = df_006.AreaShape_Extent.values[0:161] 
df_006_MajorAxisLength = df_006.AreaShape_MajorAxisLength.values[0:161] 
df_006_MinorAxisLength = df_006.AreaShape_MinorAxisLength.values[0:161] 
df_006_Compactness = df_006.AreaShape_Compactness.values[0:161] 
df_006_Eccentricity = df_006.AreaShape_Eccentricity.values[0:161]

#=======================================================================

df_007_Area = df_007.AreaShape_Area.values[0:161] 
df_007_Perimeter = df_007.AreaShape_Perimeter.values[0:161] 
df_007_Solidity = df_007.AreaShape_Solidity.values[0:161] 
df_007_Extent = df_007.AreaShape_Extent.values[0:161] 
df_007_MajorAxisLength = df_007.AreaShape_MajorAxisLength.values[0:161] 
df_007_MinorAxisLength = df_007.AreaShape_MinorAxisLength.values[0:161] 
df_007_Compactness = df_007.AreaShape_Compactness.values[0:161] 
df_007_Eccentricity = df_007.AreaShape_Eccentricity.values[0:161]

#=======================================================================

df_009_Area = df_009.AreaShape_Area.values[0:161] 
df_009_Perimeter = df_009.AreaShape_Perimeter.values[0:161] 
df_009_Solidity = df_009.AreaShape_Solidity.values[0:161] 
df_009_Extent = df_009.AreaShape_Extent.values[0:161] 
df_009_MajorAxisLength = df_009.AreaShape_MajorAxisLength.values[0:161] 
df_009_MinorAxisLength = df_009.AreaShape_MinorAxisLength.values[0:161] 
df_009_Compactness = df_009.AreaShape_Compactness.values[0:161] 
df_009_Eccentricity = df_009.AreaShape_Eccentricity.values[0:161]

#=======================================================================

df_010_Area = df_010.AreaShape_Area.values[0:161] 
df_010_Perimeter = df_010.AreaShape_Perimeter.values[0:161] 
df_010_Solidity = df_010.AreaShape_Solidity.values[0:161] 
df_010_Extent = df_010.AreaShape_Extent.values[0:161] 
df_010_MajorAxisLength = df_010.AreaShape_MajorAxisLength.values[0:161] 
df_010_MinorAxisLength = df_010.AreaShape_MinorAxisLength.values[0:161] 
df_010_Compactness = df_010.AreaShape_Compactness.values[0:161] 
df_010_Eccentricity = df_010.AreaShape_Eccentricity.values[0:161]

#=======================================================================

df_012_Area = df_012.AreaShape_Area.values[0:161] 
df_012_Perimeter = df_012.AreaShape_Perimeter.values[0:161] 
df_012_MajorAxisLength = df_012.AreaShape_MajorAxisLength.values[0:161] 
df_012_MinorAxisLength = df_012.AreaShape_MinorAxisLength.values[0:161]
df_012_Solidity = df_012.AreaShape_Solidity.values[0:161] 
df_012_Extent = df_012.AreaShape_Extent.values[0:161] 
df_012_Compactness = df_012.AreaShape_Compactness.values[0:161] 
df_012_Eccentricity = df_012.AreaShape_Eccentricity.values[0:161]

# %%
#Normalize / First.values.in each column (array)
df_002_Area_norm = df_002_Area / df_002_Area[0]
df_002_Perimeter_norm = df_002_Perimeter / df_002_Perimeter[0]
df_002_MajorAxisLength_norm = df_002_MajorAxisLength / df_002_MajorAxisLength[0]
df_002_MinorAxisLength_norm = df_002_MinorAxisLength / df_002_MinorAxisLength[0]

df_005_Area_norm = df_005_Area / df_005_Area[0]
df_005_Perimeter_norm = df_005_Perimeter / df_005_Perimeter[0]
df_005_MajorAxisLength_norm = df_005_MajorAxisLength / df_005_MajorAxisLength[0]
df_005_MinorAxisLength_norm = df_005_MinorAxisLength / df_005_MinorAxisLength[0]

df_006_Area_norm = df_006_Area / df_006_Area[0]
df_006_Perimeter_norm = df_006_Perimeter / df_006_Perimeter[0]
df_006_MajorAxisLength_norm = df_006_MajorAxisLength / df_006_MajorAxisLength[0]
df_006_MinorAxisLength_norm = df_006_MinorAxisLength / df_006_MinorAxisLength[0]

df_007_Area_norm = df_007_Area / df_007_Area[0]
df_007_Perimeter_norm = df_007_Perimeter / df_007_Perimeter[0]
df_007_MajorAxisLength_norm = df_007_MajorAxisLength / df_007_MajorAxisLength[0]
df_007_MinorAxisLength_norm = df_007_MinorAxisLength / df_007_MinorAxisLength[0]

df_009_Area_norm = df_009_Area / df_009_Area[0]
df_009_Perimeter_norm = df_009_Perimeter / df_009_Perimeter[0]
df_009_MajorAxisLength_norm = df_009_MajorAxisLength / df_009_MajorAxisLength[0]
df_009_MinorAxisLength_norm = df_009_MinorAxisLength / df_009_MinorAxisLength[0]

df_010_Area_norm = df_010_Area / df_010_Area[0]
df_010_Perimeter_norm = df_010_Perimeter / df_010_Perimeter[0]
df_010_MajorAxisLength_norm = df_010_MajorAxisLength / df_010_MajorAxisLength[0]
df_010_MinorAxisLength_norm = df_010_MinorAxisLength / df_010_MinorAxisLength[0]

df_012_Area_norm = df_012_Area / df_012_Area[0]
df_012_Perimeter_norm = df_012_Perimeter / df_012_Perimeter[0]
df_012_MajorAxisLength_norm = df_012_MajorAxisLength / df_012_MajorAxisLength[0]
df_012_MinorAxisLength_norm = df_012_MinorAxisLength / df_012_MinorAxisLength[0]

# %%
#Calculate Mean

df_DMSO_mean_Area_norm=(df_002_Area_norm+df_005_Area_norm+df_006_Area_norm)/3
df_DMSO_mean_Perimeter_norm=(df_002_Perimeter_norm+df_005_Perimeter_norm+df_006_Perimeter_norm)/3
df_DMSO_mean_MajorAxisLength_norm=(df_002_MajorAxisLength_norm+df_005_MajorAxisLength_norm+df_006_MajorAxisLength_norm)/3
df_DMSO_mean_MinorAxisLength_norm=(df_002_MinorAxisLength_norm+df_005_MinorAxisLength_norm+df_006_MinorAxisLength_norm)/3
df_DMSO_mean_Compactness=(df_002_Compactness+df_005_Compactness+df_006_Compactness)/3
df_DMSO_mean_Eccentricity=(df_002_Eccentricity+df_005_Eccentricity+df_006_Eccentricity)/3
df_DMSO_mean_Solidity=(df_002_Solidity+df_005_Solidity+df_006_Solidity)/3
df_DMSO_mean_Extent=(df_002_Extent+df_005_Extent+df_006_Extent)/3

df_TMP_mean_Area_norm=(df_007_Area_norm+df_012_Area_norm+df_009_Area_norm+df_010_Area_norm)/4
df_TMP_mean_Perimeter_norm=(df_007_Perimeter_norm+df_012_Perimeter_norm+df_009_Perimeter_norm+df_010_Perimeter_norm)/4
df_TMP_mean_MajorAxisLength_norm=(df_007_MajorAxisLength_norm+df_012_MajorAxisLength_norm+df_009_MajorAxisLength_norm+df_010_MajorAxisLength_norm)/4
df_TMP_mean_MinorAxisLength_norm=(df_007_MinorAxisLength_norm+df_012_MinorAxisLength_norm+df_009_MinorAxisLength_norm+df_010_MinorAxisLength_norm)/4
df_TMP_mean_Compactness=(df_007_Compactness+df_012_Compactness+df_009_Compactness+df_010_Compactness)/4
df_TMP_mean_Eccentricity=(df_007_Eccentricity+df_012_Eccentricity+df_009_Eccentricity+df_010_Eccentricity)/4
df_TMP_mean_Solidity=(df_007_Solidity+df_012_Solidity+df_009_Solidity+df_010_Solidity)/4
df_TMP_mean_Extent=(df_007_Extent+df_012_Extent+df_009_Extent+df_010_Extent)/4
#==============================================================================================================================

# %%
# Create Matrix
df_DMSO_means = [df_DMSO_mean_Area_norm, df_DMSO_mean_Perimeter_norm, df_DMSO_mean_MajorAxisLength_norm, df_DMSO_mean_MinorAxisLength_norm, df_DMSO_mean_Solidity, df_DMSO_mean_Extent, df_DMSO_mean_Compactness, df_DMSO_mean_Eccentricity] # Groups separate columns into 1 single array
df_DMSO_means_pandas = pd.DataFrame(data=df_DMSO_means)
df_TMP_means = [df_TMP_mean_Area_norm, df_TMP_mean_Perimeter_norm, df_TMP_mean_MajorAxisLength_norm, df_TMP_mean_MinorAxisLength_norm, df_TMP_mean_Solidity, df_TMP_mean_Extent, df_TMP_mean_Compactness, df_TMP_mean_Eccentricity] # Groups separate columns into 1 single array
df_TMP_means_pandas = pd.DataFrame(data=df_TMP_means)

# %%
df_DMSO_means_pandas_transposed = (df_DMSO_means_pandas.T)[0:41]
df_DMSO_means_pandas_transposed.columns = ['Area','Perimeter','MajorAxisLength','MinorAxisLength','Solidity','Extent','Compactness','Eccentricity']

df_TMP_means_pandas_transposed = (df_TMP_means_pandas.T)[0:41]
df_TMP_means_pandas_transposed.columns = ['Area','Perimeter','MajorAxisLength','MinorAxisLength','Solidity','Extent','Compactness','Eccentricity',]

# %%
# Compute the correlation matrix
corr_DMSO = df_DMSO_means_pandas_transposed.corr()
corr_TMP = df_TMP_means_pandas_transposed.corr()

# %%
# Generate a mask for the upper triangle
mask_dmso = np.zeros_like(corr_DMSO, dtype=bool)
mask_dmso[np.triu_indices_from(mask_dmso)] = True

# Generate a mask for the upper triangle
mask_tmp = np.zeros_like(corr_TMP, dtype=bool)
mask_tmp[np.triu_indices_from(mask_tmp)] = True

plt.subplots(figsize=(20, 25))
#=============================

plt.subplot(121)
plt.title('DMSO', fontsize=25)
# Generate a custom diverging colormap
cmap_dmso = sns.diverging_palette(1000, 0, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_DMSO, mask=mask_dmso, cmap=cmap_dmso, vmax= 1, vmin= -1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .3})
plt.tick_params(top='off', bottom='on', left='on', right='off')

plt.subplot(122)
plt.title('TMP', fontsize=25)
# Generate a custom diverging colormap
cmap_tmp = sns.diverging_palette(1000, 0, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_TMP, mask=mask_tmp, cmap=cmap_tmp, vmax= 1, vmin= -1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .3})
plt.tick_params(top='off', bottom='on', left='on', right='off')
#plt.savefig("Correlation_plot.png", format="png")
# Out:
# C:\Users\mhabi\AppData\Local\Temp\ipykernel_10244\672679625.py:12: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(121)

# %%
plt.subplots(figsize=(20, 25))
#=============================

df_DMSO_means_pandas_transposed = (df_DMSO_means_pandas.T)[0:41]
df_DMSO_means_pandas_transposed.columns = ['Area','Perimeter','MajorAxisLength','MinorAxisLength','Solidity','Extent','Compactness','Eccentricity']

df_TMP_means_pandas_transposed = (df_TMP_means_pandas.T)[0:41]
df_TMP_means_pandas_transposed.columns = ['Area','Perimeter','MajorAxisLength','MinorAxisLength','Solidity','Extent','Compactness','Eccentricity',]

# Compute the correlation matrix
corr_DMSO = df_DMSO_means_pandas_transposed.corr()
corr_TMP = df_TMP_means_pandas_transposed.corr()

# Generate a mask for the upper triangle
mask_dmso = np.zeros_like(corr_DMSO, dtype=bool)
mask_dmso[np.triu_indices_from(mask_dmso)] = True

# Generate a mask for the upper triangle
mask_tmp = np.zeros_like(corr_TMP, dtype=bool)
mask_tmp[np.triu_indices_from(mask_tmp)] = True

plt.subplot(421)
plt.title('DMSO', fontsize=25)
# Generate a custom diverging colormap
cmap_dmso = sns.diverging_palette(1000, 0, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_DMSO, mask=mask_dmso, cmap=cmap_dmso, vmax= 1, vmin= -1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .8})
plt.tick_params(top='off', bottom='on', left='on', right='off')
plt.ylabel('00-41 hr\n(TMP/DMSO Sustained)', fontsize=20)

plt.subplot(422)
plt.title('TMP', fontsize=25)
# Generate a custom diverging colormap
cmap_tmp = sns.diverging_palette(1000, 0, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_TMP, mask=mask_tmp, cmap=cmap_tmp, vmax= 1, vmin= -1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .8})
plt.tick_params(top='off', bottom='on', left='on', right='off')
#plt.savefig("Correlation_plot.png", format="png")

df_DMSO_means_pandas_transposed = (df_DMSO_means_pandas.T)[41:88]
df_DMSO_means_pandas_transposed.columns = ['Area','Perimeter','MajorAxisLength','MinorAxisLength','Solidity','Extent','Compactness','Eccentricity']

df_TMP_means_pandas_transposed = (df_TMP_means_pandas.T)[41:88]
df_TMP_means_pandas_transposed.columns = ['Area','Perimeter','MajorAxisLength','MinorAxisLength','Solidity','Extent','Compactness','Eccentricity',]

# Compute the correlation matrix
corr_DMSO = df_DMSO_means_pandas_transposed.corr()
corr_TMP = df_TMP_means_pandas_transposed.corr()

# Generate a mask for the upper triangle
mask_dmso = np.zeros_like(corr_DMSO, dtype=bool)
mask_dmso[np.triu_indices_from(mask_dmso)] = True

# Generate a mask for the upper triangle
mask_tmp = np.zeros_like(corr_TMP, dtype=bool)
mask_tmp[np.triu_indices_from(mask_tmp)] = True

plt.subplot(423)
# Generate a custom diverging colormap
cmap_dmso = sns.diverging_palette(1000, 0, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_DMSO, mask=mask_dmso, cmap=cmap_dmso, vmax= 1, vmin= -1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .8})
plt.tick_params(top='off', bottom='on', left='on', right='off')
plt.ylabel('41-88 hr\n(TMP/DMSO Sustained)\n*Change media*', fontsize=20)

plt.subplot(424)
# Generate a custom diverging colormap
cmap_tmp = sns.diverging_palette(1000, 0, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_TMP, mask=mask_tmp, cmap=cmap_tmp, vmax= 1, vmin= -1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .8})
plt.tick_params(top='off', bottom='on', left='on', right='off')
#plt.savefig("Correlation_plot.png", format="png")

df_DMSO_means_pandas_transposed = (df_DMSO_means_pandas.T)[88:140]
df_DMSO_means_pandas_transposed.columns = ['Area','Perimeter','MajorAxisLength','MinorAxisLength','Solidity','Extent','Compactness','Eccentricity']

df_TMP_means_pandas_transposed = (df_TMP_means_pandas.T)[88:140]
df_TMP_means_pandas_transposed.columns = ['Area','Perimeter','MajorAxisLength','MinorAxisLength','Solidity','Extent','Compactness','Eccentricity',]

# Compute the correlation matrix
corr_DMSO = df_DMSO_means_pandas_transposed.corr()
corr_TMP = df_TMP_means_pandas_transposed.corr()

# Generate a mask for the upper triangle
mask_dmso = np.zeros_like(corr_DMSO, dtype=bool)
mask_dmso[np.triu_indices_from(mask_dmso)] = True

# Generate a mask for the upper triangle
mask_tmp = np.zeros_like(corr_TMP, dtype=bool)
mask_tmp[np.triu_indices_from(mask_tmp)] = True

plt.subplot(425)
# Generate a custom diverging colormap
cmap_dmso = sns.diverging_palette(1000, 0, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_DMSO, mask=mask_dmso, cmap=cmap_dmso, vmax= 1, vmin= -1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .8})
plt.tick_params(top='off', bottom='on', left='on', right='off')
plt.ylabel('88-140 hr\n(TMP Removal)', fontsize=20)


plt.subplot(426)
# Generate a custom diverging colormap
cmap_tmp = sns.diverging_palette(1000, 0, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_TMP, mask=mask_tmp, cmap=cmap_tmp, vmax= 1, vmin= -1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .8})
plt.tick_params(top='off', bottom='on', left='on', right='off')
#plt.savefig("Correlation_plot.png", format="png")

df_DMSO_means_pandas_transposed = (df_DMSO_means_pandas.T)[0:140]
df_DMSO_means_pandas_transposed.columns = ['Area','Perimeter','MajorAxisLength','MinorAxisLength','Solidity','Extent','Compactness','Eccentricity']

df_TMP_means_pandas_transposed = (df_TMP_means_pandas.T)[0:140]
df_TMP_means_pandas_transposed.columns = ['Area','Perimeter','MajorAxisLength','MinorAxisLength','Solidity','Extent','Compactness','Eccentricity',]

# Compute the correlation matrix
corr_DMSO = df_DMSO_means_pandas_transposed.corr()
corr_TMP = df_TMP_means_pandas_transposed.corr()

# Generate a mask for the upper triangle
mask_dmso = np.zeros_like(corr_DMSO, dtype=bool)
mask_dmso[np.triu_indices_from(mask_dmso)] = True

# Generate a mask for the upper triangle
mask_tmp = np.zeros_like(corr_TMP, dtype=bool)
mask_tmp[np.triu_indices_from(mask_tmp)] = True

plt.subplot(427)
# Generate a custom diverging colormap
cmap_dmso = sns.diverging_palette(1000, 0, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_DMSO, mask=mask_dmso, cmap=cmap_dmso, vmax= 1, vmin= -1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .8})
plt.tick_params(top='off', bottom='on', left='on', right='off')
plt.ylabel('0-140 hr\n(TOTAL)', fontsize=20)

plt.subplot(428)
# Generate a custom diverging colormap
cmap_tmp = sns.diverging_palette(1000, 0, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_TMP, mask=mask_tmp, cmap=cmap_tmp, vmax= 1, vmin= -1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .8})
plt.tick_params(top='off', bottom='on', left='on', right='off')

plt.tight_layout()

plt.savefig("Correlation_plot_alles.png", format="png")
plt.show()
# Out:
# C:\Users\mhabi\AppData\Local\Temp\ipykernel_10244\1532270853.py:22: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(421)
